# %%
# 1. What do you mean by __name__ == '__main__'

# %% [markdown]
# ### What is a module?
#
# Any file with an extention of .py is called a module in python.
#
# Whenever we execute a program it's module name is `__main__` and this name is stored in `__name__` variable

# %%
def display():
  print('hello')

display()
print(__name__) # python ka jo interpreter  hai wo btata hai ki currently jo file execute ho rha hai wo __main__ me hai aur iska info __name__ me hai
# jb khud me run hota hai to __main__ se aur dusre me import krke hota hai to file_name se hoti hai

# time = 39:18
# Out:
# hello
# __main__

# %%
#module 1

def square(num):
    print(num**2)

def main():
    for i in range(1,11):
        square(i)


if __name__ == '__main__': # ye lagane se ab iske niche wala code kisi dusre me nhi jayega import hone ke baad
    # for i in range(1,11):
    #     square(i)
    main()

# but what if i need to give purmission to run this code in module 2 we would do this

# %%
#module 2
import module 1
user_input = int(input("Enter any number: "))
module1.square(user_input)
module1.main() #  ab issse main wala bhi use kr skte ho

# %% [markdown]
# ### Importing a module
#
# - But what is the need to import a module?
# - How to import a module

# %%
# module banane ka kya jaroort hai ak hi me sb kr lete lekin nhi 
# isse code modularity(manage krna aasan ho jata hai) pr focus krna padta hai(database,GUI,API code sv alg rhega)
# code reusability

# import a module
import test
test.hello('nitish')
# Out:
# hello nitish

# %%
# import multiple module -> user defined + builtin
import math
import test

test.hello('nitish')
print(math.floor(4.3))
# Out:
# hello nitish
# 4

# %%
# show builtin modules

# %% [markdown]
# ### Variations of import statement

# %%
# Normal
import math
import random

# %%
# clubbing together
import math,random,test

# %%
# importing specific names from module
from math import factorial,floor
from test import hello

print(factorial(5))
ceil(4.8)
# Out:
# 120
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cbe7c40736a8> in <module>
#       4
#       5 print(factorial(5))
# ----> 6 ceil(4.8)
#
# NameError: name 'ceil' is not defined

# %%
# renaming modules
import math as m
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


m.factorial(5)
# Out:
# 120

# %%
from math import factorial as f

f(5)
# Out:
# 120

# %% [markdown]
# ### Order of execution of a module

# %%
import sys
for p in sys.path:
  print(p)
# Out:
# c:\Users\Rahul\OneDrive\Desktop\CAMPUSX_PYTHON\python _for interview\week_4
# c:\Users\Rahul\anaconda3\python312.zip
# c:\Users\Rahul\anaconda3\DLLs
# c:\Users\Rahul\anaconda3\Lib
# c:\Users\Rahul\anaconda3
#
# C:\Users\Rahul\AppData\Roaming\Python\Python312\site-packages
# C:\Users\Rahul\AppData\Roaming\Python\Python312\site-packages\win32
# C:\Users\Rahul\AppData\Roaming\Python\Python312\site-packages\win32\lib
# C:\Users\Rahul\AppData\Roaming\Python\Python312\site-packages\Pythonwin
# c:\Users\Rahul\anaconda3\Lib\site-packages
# c:\Users\Rahul\anaconda3\Lib\site-packages\win32
# c:\Users\Rahul\anaconda3\Lib\site-packages\win32\lib
# c:\Users\Rahul\anaconda3\Lib\site-packages\Pythonwin

# %% [markdown]
# ### if `__name__` == `__main__`

# %%
# module and file is same
# library and package same hota hai

# %% [markdown]
# ### What are packages in Python
#
# A package in python is a directory(folder) containing similar sub packages and modules.
#
# - A particular directory is treated as package if it has `__init__.py` file in it.
# - The `__init__.py` file may be empty or contain some initialization code related to the package

# %% [markdown]
# ### What are 3rd party packages?
#
# - The python community creates packages and make it available for other programmers
# - PyPI -> Python Package Index
# - You can upload your own package
# - You can also install packages from PyPI and install using pip
# - pip is a package manager utility
# - it is automatically installed with python
