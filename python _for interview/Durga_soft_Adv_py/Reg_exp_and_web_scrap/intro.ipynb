# %% [markdown]
# regular expression ka main application --> webscraping hi hai

# %%
import re
count = 0
pattern = re.compile("ab") #ye pattern jisko find krni hai
matcher = pattern.finditer("ababaababa") #finditer me reg exp jisse patter nikalna hai dhundh kr
for match in matcher:
    count +=1
    print(match.start(), "...",match.end(), "..",match.group())

print("The number of occurrances:", count)
# Out:
# 0 ... 2 .. ab
# 2 ... 4 .. ab
# 5 ... 7 .. ab
# 7 ... 9 .. ab
# The number of occurrances: 4

# %%
import re
count = 0
matcher = re.finditer("ab","abaababa")#no-neet to use compile we can diirectly pass both in finditer()
for match in matcher:
    count +=1
    print(match.start(),"...",match.end(),"...",match.group())

print("The number of occurrences:", count)
# Out:
# 0 ... 2 ... ab
# 3 ... 5 ... ab
# 5 ... 7 ... ab
# The number of occurrences: 3

# %%
import re
count = 0
matcher = re.finditer("ab","abaababa")
for match in matcher:
    count +=1
    print(match.start(),"...",match.end(),"..",match.group())

print("The number of occurrences:",count)
# Out:
# 0 ... 2 .. ab
# 3 ... 5 .. ab
# 5 ... 7 .. ab
# The number of occurrences: 3

# %%
import re
matcher = re.finditer("b","a7b@k9z")
for match in matcher:
    print(match.start(),"....", match.end())

# %% [markdown]
# --                 **Character Class** ------------------->

# %%
#we have some important fun of re(regular expression) module
# 1.match()--> We can use match function to check the given pattern at beginning of target string

import re
s = input("Enter pattern to check")
m = re.match(s,"abcdefg")
if m!=None:
    print("match is available at the bigging of the string")
    print("start index:",m.start(),"all End Index:",m.end())

else:
    print("match is not available at the beginnning of the string")
# Out:
# match is not available at the beginnning of the string

# %% [markdown]
# **predefined character class,Qunatifiers** these all topics will be covered next to character class

# %% [markdown]
# **Important Functions of Re-Modules**

# %% [markdown]
# match()
# fullmatch()
# search()
# findall()
# finditer()
# sub()
# subn()
# split()
# compile()

# %%
#match()--> We can use match function to check the given pattern at beginning of target string. 
#If the match is available then we will get Match object, otherwise we will get None.

import re
s = input("Enter pattern to check")
print(s)
m = re.match(s,"abcdefghijklm")
if m!=None:
    print("match is available...")
    print(match.start(),"....",match.end())
else:
    print("match did not recognized...")

#remember it will return (match available only) if it will be present at begginig
# Out:
# ab
# match is available...
# 2 .... 3

# %%
#similarly for fullmatch()-> if all available then ok otherwise "False"
#search()--> it will search if specific patter available in reg exp(if yes then return 1st occurance)

# %%
#3--> Search()

import re
s = input("Enter expression to search")
print(s)

m= re.search(s,'abjcjdhesssss')

if m!=None:
    print("match available")
    print(match.start(),"...", match.end(),"......", match.group())

else:
    print("pattern is not available")
# Out:
# f
# pattern is not available

# %%
#4--> findall()-- find alll occurances of match ,This function returns a list object which contains all occurrences. 


import re 
l= re.findall("[0-9]","a7b9c5kz")
print(l)
# Out:
# ['7', '9', '5']

# %%
#5-- FInditer()-->Returns the iterator yielding a match object for each match. 
#On each match object we can call start(), end() and group() functions.

import re
itr = re.finditer("[a-z]","a7b9c5k8z") # a to z tk sb kuch return krega
for m in itr:
    print(m.start(),"...",m.end(),"....",m.group())
# Out:
# 0 ... 1 .... a
# 2 ... 3 .... b
# 4 ... 5 .... c
# 6 ... 7 .... k
# 8 ... 9 .... z

# %%
#6--sub()--> sub means substitution or replacement. 
#re.sub(regex,replacement,targetstring) 
#In the target string every matched pattern will be replaced with provided replacement.

import re
s = re.sub("[a-z]","#","a7b9c5k8z")
print(s)
# Out:
# #7#9#5#8#

# %%
#7--subn()--> It is exactly same as sub except it can also returns the number of replacements. 
#This function returns a tuple where first element is result string and second element is 
#number of replacements. (resultstring, number of replacements)



import re
t = re.subn("[a-z]","#","a7b9c5k8z")
print(t)
print("The result String:",t[0])
print("The number of replacements:",t[1])
# Out:
# ('#7#9#5#8#', 5)
# The result String: #7#9#5#8#
# The number of replacements: 5

# %%
#8--split()-->If we want to split the given target string according to a particular pattern then we 
#should go for split() function. 
#This function returns list of all tokens


import re 
l = re.split(",","sunny,bunny")
print(l)
for t in l:
    print(t)
# Out:
# ['sunny', 'bunny']
# sunny
# bunny

# %%
#9--^ symbol--> We can use ^ symbol to check whether the given target string starts with our provided pattern or not. 
#Eg: res = re.search("^Learn",s) 
# If the target string starts with learn then it will return Match object,otherwise returns None.


import re

s = "Learning python is very easy"
res = re.search("^Learn",s)
if res!=None:
    print("Target string started with Learn")
else:
    print("Target string not started with Learn")
# Out:
# Target string started with Learn

# %%
#10-- $ symbol--> We can use $ symbol to check whether the given target string ends with our provided pattern or not. 
#Eg: res = re.search("Easy$",s) 
#If the target string ends with Easy then it will return Match object,otherwise returns None.


import re
s = "Learning python is easy"
res = re.search("Easy$",s,re.IGNORECASE)#we can use re.IGNORECASE to avoid upper/lowe case
if res!=None:
    print("Target string ends with Easy")
else:
    print("Target string Not Ends with Easy")
# Out:
# Target string ends with Easy

# %%
#write a program to check wether a given mobile number is valid number or not


import re
n = input("Enter number: ")
m = re.fullmatch("[7-9]\d{9}",n)
if m!=None:
    print("valid mobile number: ")
else:
    print("invalid mobile number...")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_15672\2069171197.py:6: SyntaxWarning: invalid escape sequence '\d'
#   m = re.fullmatch("[7-9]\d{9}",n)
# valid mobile number:

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Rahul\OneDrive\Desktop\CAMPUSX_PYTHON\python _for interview\Durga_soft_Adv_py\Reg_exp_and_web_scrap

# %%
#5)--> Write a Python Program to extract all Mobile Numbers present in input.txt where Numbers are mixed with Normal Text Data

import re
f1 = open("input.txt","r")
f2 = open("output.txt","w")

for line in f1:
    lst = re.findall(r"[7-9]\d{9}",line) # use r to avoid this escape-sequence error
    for n in lst:
        f2.write(n+"\n")
print("Extracted all mobile number into output.txt")
f1.close()
f2.close()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\R'
# <>:4: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_18812\2624938180.py:4: SyntaxWarning: invalid escape sequence '\R'
#   f1 = open("Users\Rahul\OneDrive\Desktop\CAMPUSX_PYTHON\python _for interview\Durga_soft_Adv_py\Reg_exp_and_web_scrap\input.txt","r")
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_18812\2624938180.py:4: SyntaxWarning: invalid escape sequence '\R'
#   f1 = open("Users\Rahul\OneDrive\Desktop\CAMPUSX_PYTHON\python _for interview\Durga_soft_Adv_py\Reg_exp_and_web_scrap\input.txt","r")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 4
#       1 #5)--> Write a Python Program to extract all Mobile Numbers present in input.txt where Numbers are mixed with Normal Text Data
#       3 import re
# ...

# %%
import re
import urllib.request

sites = "google rediff".split()

for s in sites:
    print("Searching...", s)
    
    u = urllib.request.urlopen("https://" + s + ".com")
    text = u.read().decode("utf-8")   # decode bytes
    
    title = re.findall(r"<title>(.*?)</title>", text, re.I)
    
    if title:
        print(title[0])
    else:
        print("No title found")
# Out:
# Searching... google
# Google
# Searching... rediff
# Rediff.com: News | Rediffmail | Stock Quotes | Rediff Gurus

# %% [markdown]
# 1. Program to get all Phone Numbers of redbus.in by using Web
# Scraping and Regular Expressions

# %%
import re,urllib

import urllib.request
u = urllib.request.urlopen("https://www.redbus.in/info/contactus")
text = u.read()
numbers = re.findall("[0-9]{7}[0-9-]+",str(text),re.I)
for n in numbers:
    print(n)
# Out:
# 9945600000
# 9513595131
