# %% [markdown]
# Exception Handling is always associated with runtime errors.
#
#
#   The main purpose of assertions is for debugging purposes.
#
#
#   debugging: The process of identifying and fixing the bug is called debugging.
#
#
#
#     defect(find by testing team)   bug(checked by DEV team)   erro
#
#     1. Development Environment/Dev Environment
#     2. Test Environment
#     3. Production/Live Environment
#
#
#     Defect: Deviation in the expected output and original
#
#
#     output Bug: If dev team accepted the defect(by developer)
#
# if bug happen found in production then it is (Error)

# %% [markdown]
# the most common way of debugging is (print())--> statement and we can use assertion in that place to avoid deleting print()--> statement
#
# Assetion need not to be delete if we say do not execute on client machine then it will not execute
#
#
# Assertion concept is appicable only for Dev and Test Environment
