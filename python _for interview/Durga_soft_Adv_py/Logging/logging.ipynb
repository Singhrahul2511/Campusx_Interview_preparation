# %%
import logging
logging.basicConfig(format='%(asctime)s- %(levelname)s - %(message)s')
logging.critical('it is critical message')
logging.error('it is error')
logging.warning('it is waringin message')
logging.info('its info meaage')
logging.debug('it is debug message')
# Out:
# CRITICAL - it is critical message
# ERROR - it is error
# WARNING - it is waringin message

# %%
class Solution:
    def rotate(self, matrix):

        """
        Do not return anything, modify matrix in-place instead.
        """
        r = len(matrix)
        c = len(matrix[0])
        lst = [[0]*3 for _ in range(r)]
        for i in range(r):
            for j in range(c):
                lst[j][(r-1)-i] = matrix[i][j]
        print(lst)

obj = Solution()
obj.rotate([[1,2,3],[4,5,6],[7,8,9]])
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]

# %%
class Solution:
    def rotate(self, matrix):

        """
        Do not return anything, modify matrix in-place instead.
        """
        r = len(matrix)
        c = len(matrix[0])
        # lst = [[0]*3 for _ in range(r)]
        for i in range(r):
            for j in range(c):
                matrix[j][(r-1)-i],matrix[i][j] = matrix[i][j],matrix[j][(r-1)-i]
        print(matrix)

obj = Solution()
obj.rotate([[1,2,3],[4,5,6],[7,8,9]])
# Out:
# [[7, 4, 9], [2, 5, 8], [1, 6, 3]]
