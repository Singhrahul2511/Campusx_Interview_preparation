# %% [markdown]
#  2 things we will study here:-------
#
#
#  1. WSAI ---> web server getway Interface
#  2. Jinja2 Template Engine
#
#
# FLASK = web framework which is created using python programming language
